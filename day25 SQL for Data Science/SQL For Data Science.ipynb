# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("chinook.db")

# %%
cur = conn.cursor()

# %%
for row in cur.execute("SELECT name FROM sqlite_master WHERE type='table';"):
    print(row)
# Out:
# ('albums',)
# ('sqlite_sequence',)
# ('artists',)
# ('customers',)
# ('employees',)
# ('genres',)
# ('invoices',)
# ('invoice_items',)
# ('media_types',)
# ('playlists',)
# ('playlist_track',)
# ('tracks',)
# ('sqlite_stat1',)

# %% [markdown]
# ***Retriving rows***

# %%
cur.execute("select * from albums limit 7;")

# %%
results = cur.fetchall()
print(results)
# Out:
# [(1, 'For Those About To Rock We Salute You', 1), (2, 'Balls to the Wall', 2), (3, 'Restless and Wild', 2), (4, 'Let There Be Rock', 1), (5, 'Big Ones', 3), (6, 'Jagged Little Pill', 4), (7, 'Facelift', 5)]

# %%
pd.read_sql_query("SELECT * from artists limit 5;",conn)
# Out:
#    ArtistId               Name
# 0         0             Manavi
# 1         1              AC/DC
# 2         2             Accept
# 3         3          Aerosmith
# 4         4  Alanis Morissette

# %%
pd.read_sql_query("SELECT ArtistId, Name FROM artists WHERE ArtistId<10;",conn,index_col="ArtistId")
# Out:
#                           Name
# ArtistId
# 0                       Manavi
# 1                        AC/DC
# 2                       Accept
# 3                    Aerosmith
# 4            Alanis Morissette
# 5              Alice In Chains
# 6         Antônio Carlos Jobim
# 7                 Apocalyptica
# 8                   Audioslave

# %% [markdown]
# **Updating rows**

# %%
values = ('shape',8)
cur.execute("update artists set Name=? where ArtistId=?", values)
conn.commit()

# %%
pd.read_sql_query("select * from artists where ArtistId=8;", conn)
# Out:
# Empty DataFrame
# Columns: [ArtistId, Name]
# Index: []

# %% [markdown]
# **Deleting rows**

# %%
values = (8, )
cur.execute("delete from artists where ArtistId=?", values)
conn.commit()

# %%
pd.read_sql_query("select * from artists where ArtistId=8;", conn)
# Out:
# Empty DataFrame
# Columns: [ArtistId, Name]
# Index: []

# %% [markdown]
# **Inserting row**

# %%
cur.execute("insert into artists values (367,'kirti')")

# %%
conn.commit()

# %%
pd.read_sql_query("select * from artists where ArtistId=367;", conn)
# Out:
#    ArtistId   Name
# 0       366  kirti

# %% [markdown]
# ## Joins

# %% [markdown]
# **Inner Join**

# %%
df_artists=pd.read_sql_query("SELECT * FROM artists limit 10",conn)
df_tracks=pd.read_sql_query("SELECT * FROM tracks limit 10",conn)

# %%
df_artists.merge(df_tracks,how="inner",left_on="ArtistId",right_on="TrackId")
# Out:
#    ArtistId                Name_x  TrackId  \
# 0         1                 AC/DC        1
# 1         2                Accept        2
# 2         3             Aerosmith        3
# 3         4     Alanis Morissette        4
# 4         5       Alice In Chains        5
# 5         6  Antônio Carlos Jobim        6
# 6         7          Apocalyptica        7
# 7         8            Audioslave        8
# 8        10          Billy Cobham       10
#
#                                     Name_y  AlbumId  MediaTypeId  GenreId  \
# 0  For Those About To Rock (We Salute You)        1            1        1
# 1                        Balls to the Wall        2            2        1
# 2                          Fast As a Shark        3            2        1
# 3                        Restless and Wild        3            2        1
# 4                     Princess of the Dawn        3            2        1
# 5                    Put The Finger On You        1            1        1
# 6                          Let's Get It Up        1            1        1
# 7                         Inject The Venom        1            1        1
# 8                               Evil Walks        1            1        1
#
#                                             Composer  Milliseconds     Bytes  \
# 0          Angus Young, Malcolm Young, Brian Johnson        343719  11170334
# 1                                               None        342562   5510424
# 2  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619   3990994
# 3  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051   4331779
# 4                         Deaffy & R.A. Smith-Diesel        375418   6290521
# 5          Angus Young, Malcolm Young, Brian Johnson        205662   6713451
# 6          Angus Young, Malcolm Young, Brian Johnson        233926   7636561
# 7          Angus Young, Malcolm Young, Brian Johnson        210834   6852860
# 8          Angus Young, Malcolm Young, Brian Johnson        263497   8611245
#
#    UnitPrice
# 0       0.99
# 1       0.99
# 2       0.99
# 3       0.99
# 4       0.99
# 5       0.99
# 6       0.99
# 7       0.99
# 8       0.99

# %%
pd.read_sql_query("SELECT * FROM artists,tracks WHERE artists.ArtistId=tracks.TrackId limit 5",conn)
# Out:
#    ArtistId               Name  TrackId  \
# 0         1              AC/DC        1
# 1         2             Accept        2
# 2         3          Aerosmith        3
# 3         4  Alanis Morissette        4
# 4         5    Alice In Chains        5
#
#                                       Name  AlbumId  MediaTypeId  GenreId  \
# 0  For Those About To Rock (We Salute You)        1            1        1
# 1                        Balls to the Wall        2            2        1
# 2                          Fast As a Shark        3            2        1
# 3                        Restless and Wild        3            2        1
# 4                     Princess of the Dawn        3            2        1
#
#                                             Composer  Milliseconds     Bytes  \
# 0          Angus Young, Malcolm Young, Brian Johnson        343719  11170334
# 1                                               None        342562   5510424
# 2  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619   3990994
# 3  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051   4331779
# 4                         Deaffy & R.A. Smith-Diesel        375418   6290521
#
#    UnitPrice
# 0       0.99
# 1       0.99
# 2       0.99
# 3       0.99
# 4       0.99

# %% [markdown]
# **Right Join**

# %%
df_artists.merge(df_tracks, how="right", left_on = "ArtistId", right_on="TrackId")
# Out:
#    ArtistId                Name_x  TrackId  \
# 0       1.0                 AC/DC        1
# 1       2.0                Accept        2
# 2       3.0             Aerosmith        3
# 3       4.0     Alanis Morissette        4
# 4       5.0       Alice In Chains        5
# 5       6.0  Antônio Carlos Jobim        6
# 6       7.0          Apocalyptica        7
# 7       8.0            Audioslave        8
# 8      10.0          Billy Cobham       10
# 9       NaN                   NaN        9
#
#                                     Name_y  AlbumId  MediaTypeId  GenreId  \
# 0  For Those About To Rock (We Salute You)        1            1        1
# 1                        Balls to the Wall        2            2        1
# 2                          Fast As a Shark        3            2        1
# 3                        Restless and Wild        3            2        1
# 4                     Princess of the Dawn        3            2        1
# 5                    Put The Finger On You        1            1        1
# 6                          Let's Get It Up        1            1        1
# 7                         Inject The Venom        1            1        1
# 8                               Evil Walks        1            1        1
# 9                               Snowballed        1            1        1
#
#                                             Composer  Milliseconds     Bytes  \
# 0          Angus Young, Malcolm Young, Brian Johnson        343719  11170334
# 1                                               None        342562   5510424
# 2  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619   3990994
# 3  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051   4331779
# 4                         Deaffy & R.A. Smith-Diesel        375418   6290521
# 5          Angus Young, Malcolm Young, Brian Johnson        205662   6713451
# 6          Angus Young, Malcolm Young, Brian Johnson        233926   7636561
# 7          Angus Young, Malcolm Young, Brian Johnson        210834   6852860
# 8          Angus Young, Malcolm Young, Brian Johnson        263497   8611245
# 9          Angus Young, Malcolm Young, Brian Johnson        203102   6599424
#
#    UnitPrice
# 0       0.99
# 1       0.99
# 2       0.99
# 3       0.99
# 4       0.99
# 5       0.99
# 6       0.99
# 7       0.99
# 8       0.99
# 9       0.99

# %% [markdown]
# **Left Join**

# %%
df_artists.merge(df_tracks, how="left", left_on = "ArtistId", right_on="TrackId")
# Out:
#    ArtistId                Name_x  TrackId  \
# 0         0                Manavi      NaN
# 1         1                 AC/DC      1.0
# 2         2                Accept      2.0
# 3         3             Aerosmith      3.0
# 4         4     Alanis Morissette      4.0
# 5         5       Alice In Chains      5.0
# 6         6  Antônio Carlos Jobim      6.0
# 7         7          Apocalyptica      7.0
# 8         8            Audioslave      8.0
# 9        10          Billy Cobham     10.0
#
#                                     Name_y  AlbumId  MediaTypeId  GenreId  \
# 0                                      NaN      NaN          NaN      NaN
# 1  For Those About To Rock (We Salute You)      1.0          1.0      1.0
# 2                        Balls to the Wall      2.0          2.0      1.0
# 3                          Fast As a Shark      3.0          2.0      1.0
# 4                        Restless and Wild      3.0          2.0      1.0
# 5                     Princess of the Dawn      3.0          2.0      1.0
# 6                    Put The Finger On You      1.0          1.0      1.0
# 7                          Let's Get It Up      1.0          1.0      1.0
# 8                         Inject The Venom      1.0          1.0      1.0
# 9                               Evil Walks      1.0          1.0      1.0
#
#                                             Composer  Milliseconds  \
# 0                                                NaN           NaN
# 1          Angus Young, Malcolm Young, Brian Johnson      343719.0
# 2                                               None      342562.0
# 3  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...      230619.0
# 4  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...      252051.0
# 5                         Deaffy & R.A. Smith-Diesel      375418.0
# 6          Angus Young, Malcolm Young, Brian Johnson      205662.0
# 7          Angus Young, Malcolm Young, Brian Johnson      233926.0
# 8          Angus Young, Malcolm Young, Brian Johnson      210834.0
# 9          Angus Young, Malcolm Young, Brian Johnson      263497.0
#
#         Bytes  UnitPrice
# 0         NaN        NaN
# 1  11170334.0       0.99
# 2   5510424.0       0.99
# 3   3990994.0       0.99
# 4   4331779.0       0.99
# 5   6290521.0       0.99
# 6   6713451.0       0.99
# 7   7636561.0       0.99
# 8   6852860.0       0.99
# 9   8611245.0       0.99

# %% [markdown]
# **Outer Join**

# %%
df_artists.merge(df_tracks, how="outer", left_on = "ArtistId", right_on="TrackId")
# Out:
#     ArtistId                Name_x  TrackId  \
# 0        0.0                Manavi      NaN
# 1        1.0                 AC/DC      1.0
# 2        2.0                Accept      2.0
# 3        3.0             Aerosmith      3.0
# 4        4.0     Alanis Morissette      4.0
# 5        5.0       Alice In Chains      5.0
# 6        6.0  Antônio Carlos Jobim      6.0
# 7        7.0          Apocalyptica      7.0
# 8        8.0            Audioslave      8.0
# 9       10.0          Billy Cobham     10.0
# 10       NaN                   NaN      9.0
#
#                                      Name_y  AlbumId  MediaTypeId  GenreId  \
# 0                                       NaN      NaN          NaN      NaN
# 1   For Those About To Rock (We Salute You)      1.0          1.0      1.0
# 2                         Balls to the Wall      2.0          2.0      1.0
# 3                           Fast As a Shark      3.0          2.0      1.0
# 4                         Restless and Wild      3.0          2.0      1.0
# 5                      Princess of the Dawn      3.0          2.0      1.0
# 6                     Put The Finger On You      1.0          1.0      1.0
# 7                           Let's Get It Up      1.0          1.0      1.0
# 8                          Inject The Venom      1.0          1.0      1.0
# 9                                Evil Walks      1.0          1.0      1.0
# 10                               Snowballed      1.0          1.0      1.0
#
#                                              Composer  Milliseconds  \
# 0                                                 NaN           NaN
# 1           Angus Young, Malcolm Young, Brian Johnson      343719.0
# 2                                                None      342562.0
# 3   F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...      230619.0
# 4   F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...      252051.0
# 5                          Deaffy & R.A. Smith-Diesel      375418.0
# 6           Angus Young, Malcolm Young, Brian Johnson      205662.0
# 7           Angus Young, Malcolm Young, Brian Johnson      233926.0
# 8           Angus Young, Malcolm Young, Brian Johnson      210834.0
# 9           Angus Young, Malcolm Young, Brian Johnson      263497.0
# 10          Angus Young, Malcolm Young, Brian Johnson      203102.0
#
#          Bytes  UnitPrice
# 0          NaN        NaN
# 1   11170334.0       0.99
# 2    5510424.0       0.99
# 3    3990994.0       0.99
# 4    4331779.0       0.99
# 5    6290521.0       0.99
# 6    6713451.0       0.99
# 7    7636561.0       0.99
# 8    6852860.0       0.99
# 9    8611245.0       0.99
# 10   6599424.0       0.99
